# %%
import pandas as pd

df = pd.read_excel('data/Colombianos_registrados_en_el_exterior_20251113 (1).xlsx')

# %%
#imprimimos el df para ver su contenido
df
# Out:
#                   País Código ISO país     Ciudad de Residencia  \
# 0       ESTADOS UNIDOS             USA       WASHINGTON/SEATTLE
# 1       ESTADOS UNIDOS             USA           TEXAS/PASADENA
# 2       ESTADOS UNIDOS             USA      NEW YORK/NUEVA YORK
# 3               CANADA             CAN          ALBERTA/CALGARY
# 4       ESTADOS UNIDOS             USA       FLORIDA/BAY HARBOR
# ...                ...             ...                      ...
# 624096          CANADA             CAN          ALBERTA/CALGARY
# 624097  ESTADOS UNIDOS             USA  MASSACHUSETTS/HAVERHILL
# 624098       AUSTRALIA             AUS      QUEENSLAND/BRISBANE
# 624099  ESTADOS UNIDOS             USA          FLORIDA/ORLANDO
# 624100  ESTADOS UNIDOS             USA        NEW YORK/BROOKLYN
#
#        Oficina de registro Grupo edad  Edad (años)  \
# 0         C. SAN FRANCISCO     ADULTO           32
# 1               C. HOUSTON     ADULTO           52
# 2            C. NUEVA YORK     ADULTO           33
# 3               C. CALGARY     ADULTO           30
# 4                 C. MIAMI     ADULTO           46
# ...                    ...        ...          ...
# 624096          C. CALGARY     ADULTO           50
# 624097           C. BOSTON     ADULTO           35
# 624098           C. SYDNEY     ADULTO           40
# 624099          C. ORLANDO     ADULTO           36
# 624100       C. NUEVA YORK     ADULTO           46
#
#                                    Área Conocimiento  \
# 0                                            NINGUNA
# 1                                            NINGUNA
# 2                        CIENCIAS SOCIALES Y HUMANAS
# 3                        CIENCIAS SOCIALES Y HUMANAS
# 4       ECONOM�A, ADMINISTRACI�N CONTADURIA Y AFINES
# ...                                              ...
# 624096                          CIENCIAS DE LA SALUD
# 624097                                       NINGUNA
# 624098  ECONOM�A, ADMINISTRACI�N CONTADURIA Y AFINES
# 624099                                     NO INDICA
# 624100                                  BELLAS ARTES
#
#                            Sub Area Conocimiento         Nivel Académico  \
# 0                                        NINGUNA            BACHILLERATO
# 1                                        NINGUNA               NO INDICA
# 2       PERIODISMO, COMUNICACI�N SOCIAL Y AFINES  PREGRADO - PROFESIONAL
# 3       PERIODISMO, COMUNICACI�N SOCIAL Y AFINES  PREGRADO - PROFESIONAL
# 4                                 ADMINISTRACI�N               NO INDICA
# ...                                          ...                     ...
# 624096                                ENFERMER�A               NO INDICA
# 624097                                   NINGUNA                 NINGUNO
# 624098                        CONTADUR�A P�BLICA               NO INDICA
# 624099                                 NO INDICA    POSTGRADO - MAESTRIA
# 624100        ARTES PL�STICAS, VISUALES Y AFINES  PREGRADO - PROFESIONAL
#
#        Estado civil     Género Etnia de la persona  Estatura (CM)  \
# 0           SOLTERO   FEMENINO                OTRO             -1
# 1            CASADO   FEMENINO                OTRO             -1
# 2           SOLTERO  MASCULINO                OTRO             -1
# 3            CASADO   FEMENINO                OTRO             -1
# 4            CASADO  MASCULINO                OTRO             -1
# ...             ...        ...                 ...            ...
# 624096       CASADO   FEMENINO             NINGUNA             -1
# 624097      SOLTERO   FEMENINO                OTRO             -1
# 624098  DESCONOCIDO   FEMENINO                OTRO             -1
# 624099      SOLTERO   FEMENINO             NINGUNA            158
# 624100       CASADO  MASCULINO             NINGUNA             -1
#
#                        Ciudad de Nacimiento              Localización  \
# 0         ESTADOS UNIDOS/WASHINGTON/REDMOND    (37.09024, -95.712891)
# 1             COLOMBIA/VALLE DEL CAUCA/CALI    (37.09024, -95.712891)
# 2             COLOMBIA/VALLE DEL CAUCA/CALI    (37.09024, -95.712891)
# 3              COLOMBIA/CUNDINAMARCA/BOGOTA  (56.130366, -106.346771)
# 4              ESTADOS UNIDOS/FLORIDA/MIAMI    (37.09024, -95.712891)
# ...                                     ...                       ...
# 624096            COLOMBIA/CALDAS/MANIZALES  (56.130366, -106.346771)
# 624097  ESTADOS UNIDOS/MASSACHUSETTS/LOWELL    (37.09024, -95.712891)
# 624098         COLOMBIA/CUNDINAMARCA/BOGOTA  (-25.274398, 133.775136)
# 624099      COLOMBIA/ATLANTICO/BARRANQUILLA    (37.09024, -95.712891)
# 624100                        (NO REGISTRA)    (37.09024, -95.712891)
#
#        Fecha de Registro  Cantidad de personas
# 0                2023-02                     1
# 1                2018-04                     1
# 2                2024-05                     1
# 3                2024-11                     1
# 4                2022-02                     1
# ...                  ...                   ...
# 624096           2016-12                     1
# 624097           2024-02                     1
# 624098           2017-09                     1
# 624099           2014-09                     1
# 624100           2023-10                     1
#
# [624101 rows x 17 columns]

# %%
#mirar los valores unicos de las columnas con posibles errores
print(df['Área Conocimiento'].unique())
print(df['Sub Area Conocimiento'].unique())
print(df['Nivel Académico'].unique())
print(df['Etnia de la persona'].unique())
# Out:
# ['NINGUNA' 'CIENCIAS SOCIALES Y HUMANAS'
#  'ECONOM�A, ADMINISTRACI�N CONTADURIA Y AFINES'
#  'INGENIER�A, ARQUITECTURA Y AFINES' 'NO INDICA' 'CIENCIAS DE LA SALUD'
#  'AGRONOM�A, VETERINARIA Y AFINES' 'SERVICIOS' 'BELLAS ARTES'
#  'AGRONOM�A, VETERINARIA Y ZOOTECNIA' 'CIENCIAS DE LA EDUCACI�N'
#  'CIENCIAS SOCIALES, PERIODISMO E INFORMACI�N'
#  'MATEM�TICAS Y CIENCIAS NATURALES' 'SALUD Y BIENESTAR' 'AVIACI�N'
#  'ADMINISTRACI�N DE EMPRESAS Y DERECHO' 'EDUCACI�N' 'COCINA Y CULINARIA'
#  'INGENIER�A, INDUSTRIA Y CONSTRUCCI�N' '(NO REGISTRA)'
#  'ARTES Y HUMANIDADES' 'CIENCIAS NATURALES, MATEM�TICAS Y ESTAD�STICA'
#  'TECNOLOG�AS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)'
#  'PROGRAMAS Y CERTIFICACIONES GEN�RICAS'
#  'AGROPECUARIO, SILVICULTURA, PESCA, Y VETERINARIA']
# ['NINGUNA' 'PERIODISMO, COMUNICACI�N SOCIAL Y AFINES' 'ADMINISTRACI�N'
#  'INGENIER�A INDUSTRIAL Y AFINES' 'SOCIOLOG�A, TRABAJO SOCIAL Y AFINES'
#  'NO INDICA' 'OTROS ESTUDIOS EN CIENCIAS SOCIALES Y HUMANAS' 'MEDICINA'
#  'ARQUITECTURA' 'CONTADUR�A P�BLICA' 'ENFERMER�A'
#  'INGENIER�A CIVIL Y AFINES' 'AGRONOM�A' 'AVIACI�N'
#  'INGENIER�A MEC�NICA Y AFINES' 'OTRO PROGRAMA DE SALUD'
#  'PSICOLOG�A Y AFINES' 'SALUD OCUPACIONAL (HSEQ)' 'ECONOM�A' 'DISE�O'
#  'INGENIER�A EL�CTRICA Y AFINES' 'ZOOTECNIA'
#  'INGENIER�A ELECTR�NICA, TELECOMUNICACIONES Y AFINES'
#  'INGENIER�A EN SISTEMAS, TELEM�TICA Y AFINES' 'TERAPIAS'
#  'MEDICINA VETERINARIA' 'CIENCIA POL�TICA Y/O RELACIONES INTERNACIONALES'
#  'EDUCACI�N' 'OTRAS INGENIER�AS' 'DERECHO Y AFINES' 'PUBLICIDAD Y AFINES'
#  'FILOSOF�A, TEOLOG�A Y AFINES' 'COCINA Y CULINARIA' 'GEOLOG�A'
#  'ODONTOLOG�A' 'INGENIER�A QU�MICA Y AFINES'
#  'OTRO PROGRAMA DE BELLAS ARTES' 'OTROS PROGRAMAS DE CIENCIAS NATURALES'
#  'ARTES DRAM�TICAS Y REPRESENTATIVAS' 'BACTERIOLOG�A' 'SALUD P�BLICA'
#  'MATEM�TICAS, ESTAD�STICA Y AFINES' 'ARTES PL�STICAS, VISUALES Y AFINES'
#  'INSTRUMENTACI�N QUIR�RGICA' 'BIOLOG�A, MICROBIOLOG�A Y AFINES'
#  'INGENIER�A DE MINAS, METALURGIA Y AFINES'
#  'INGENIER�A ADMINISTRATIVA Y AFINES'
#  'INGENIER�A AGR�COLA, FORESTAL Y AFINES'
#  'DEPORTES, EDUCACI�N F�SICA Y RECREACI�N' 'GEOGRAF�A O HISTORIA'
#  'INGENIER�A AMBIENTAL, SANITARIA Y AFINES' '(NO REGISTRA)'
#  'NUTRICI�N Y DIET�TICA' 'DERECHO' 'ANTROPOLOG�A O ARTES LIBERALES'
#  'LENGUAS MODERNAS, FILOLOG�A, LING��STICA Y AFINES'
#  'INGENIER�A AGROINDUSTRIAL, ALIMENTOS Y AFINES' 'M�SICA'
#  'FORMACI�N MILITAR' 'INGENIER�A BIOM�DICA Y AFINES' 'QU�MICA Y AFINES'
#  'INGENIER�A DE PETR�LEOS' 'F�SICA'
#  'TECNOLOG�AS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)' 'OPTOMETR�A'
#  'BIBLIOTECOLOG�A' 'INGENIER�A AGRON�MICA, PECUARIA Y AFINES']
# ['BACHILLERATO' 'NO INDICA' 'PREGRADO - PROFESIONAL'
#  'POSTGRADO - ESPECIALIZACI�N' 'PRIMARIA' 'POSTGRADO - MAESTRIA'
#  'PREGRADO - T�CNICO PROFESIONAL' 'POSTGRADO - DOCTORADO' 'NINGUNO'
#  'PREGRADO - TECNOL�GICO' '(NO REGISTRA)' 'SIN PROFESI�N' 'UNIVERSITARIO'
#  'T�CNICA PROFESIONAL' 'ESPECIALIZACI�N' 'MAESTRIA' 'DOCTORADO'
#  'TECNOL�GICA']
# ['OTRO' 'NINGUNA' 'SIN ETNIA REGISTRADA' 'AFRODESCENDIENTE' 'IND�GENA'
#  'RAIZAL DEL ARCHIPIELAGO DE SAN ANDRES' 'GITANO'
#  'PALENQUERO DE SAN BASILIO']

# %%
## LIMPIEZA DE DATOS
# Diccionarios de reemplazo

remplasos_area = {
    'ECONOM�A': 'ECONOMIA',
    'ADMINISTRACI�N': 'ADMINISTRACION',
    'INGENIER�A': 'INGENIERIA',
    'AGRONOM�A': 'AGRONOMIA',
    'CIENCIAS DE LA EDUCACI�N': 'CIENCIAS DE LA EDUCACION',
    'CIENCIAS SOCIALES, PERIODISMO E INFORMACI�N': 'CIENCIAS SOCIALES, PERIODISMO E INFORMACION',
    'MATEM�TICAS': 'MATEMATICAS',
    'TECNOLOG�AS': 'TECNOLOGIAS',
    'PROGRAMAS Y CERTIFICACIONES GEN�RICAS': 'PROGRAMAS Y CERTIFICACIONES GENERICAS',
    'ESTAD�STICA': 'ESTADISTICA',
    'AVIACI�N': 'AVIACION',
    'EDUCACI�N': 'EDUCACION',
    'DISE�O': 'DISENO',
    'F�SICA': 'FISICA',
    'M�SICA': 'MUSICA',
    'NUTRICI�N': 'NUTRICION',
    'ANTROPOLOG�A': 'ANTROPOLOGIA',
    'LING��STICA': 'LINGUISTICA',
    'QU�MICA': 'QUIMICA',
    'ODONTOLOG�A': 'ODONTOLOGIA',
    'GEOLOG�A': 'GEOLOGIA',
    'FILOSOF�A': 'FILOSOFIA',
    'INSTRUMENTACI�N': 'INSTRUMENTACION',
    'SALUD P�BLICA': 'SALUD PUBLICA',
    'OPTOMETR�A': 'OPTOMETRIA',
    'TECNOLOGIAS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)':
    'TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION (TIC)',
    'INGENIERIA, INDUSTRIA Y CONSTRUCCI�N': 'INGENIERIA, INDUSTRIA Y CONSTRUCCION',
    'INGENIERIA, INDUSTRIA Y CONSTRUCCI�N': 'INGENIERIA, INDUSTRIA Y CONSTRUCCION'    
}

# Diccionario con todos los reemplazos para 'Sub Area Conocimiento'
remplazos_subarea = {
    'PERIODISMO, COMUNICACI�N SOCIAL Y AFINES': 'PERIODISMO, COMUNICACION SOCIAL Y AFINES',
    'ADMINISTRACI�N': 'ADMINISTRACION',
    'INGENIER�A INDUSTRIAL Y AFINES': 'INGENIERIA INDUSTRIAL Y AFINES',
    'SOCIOLOG�A, TRABAJO SOCIAL Y AFINES': 'SOCIOLOGIA, TRABAJO SOCIAL Y AFINES',
    'CONTADUR�A P�BLICA': 'CONTADURIA PUBLICA',
    'ENFERMER�A': 'ENFERMERIA',
    'INGENIER�A CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
    'AGRONOM�A': 'AGRONOMIA',
    'INGENIER�A MEC�NICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
    'PSICOLOG�A Y AFINES': 'PSICOLOGIA Y AFINES',
    'ECONOM�A': 'ECONOMIA',
    'DISE�O': 'DISENO',
    'INGENIER�A EL�CTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
    'INGENIER�A ELECTR�NICA, TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES',
    'INGENIER�A EN SISTEMAS, TELEM�TICA Y AFINES': 'INGENIERIA EN SISTEMAS, TELEMATICA Y AFINES',
    'CIENCIA POL�TICA Y/O RELACIONES INTERNACIONALES': 'CIENCIA POLITICA Y/O RELACIONES INTERNACIONALES',
    'EDUCACI�N': 'EDUCACION',
    'FILOSOF�A, TEOLOG�A Y AFINES': 'FILOSOFIA, TEOLOGIA Y AFINES',
    'GEOLOG�A': 'GEOLOGIA',
    'ODONTOLOG�A': 'ODONTOLOGIA',
    'INGENIER�A QU�MICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
    'ARTES DRAM�TICAS Y REPRESENTATIVAS': 'ARTES DRAMATICAS Y REPRESENTATIVAS',
    'BACTERIOLOG�A': 'BACTERIOLOGIA',
    'SALUD P�BLICA': 'SALUD PUBLICA',
    'MATEM�TICAS, ESTAD�STICA Y AFINES': 'MATEMATICAS, ESTADISTICA Y AFINES',
    'ARTES PL�STICAS, VISUALES Y AFINES': 'ARTES PLASTICAS, VISUALES Y AFINES',
    'INSTRUMENTACI�N QUIR�RGICA': 'INSTRUMENTACION QUIRURGICA',
    'BIOLOG�A, MICROBIOLOG�A Y AFINES': 'BIOLOGIA, MICROBIOLOGIA Y AFINES',
    'INGENIER�A DE MINAS, METALURGIA Y AFINES': 'INGENIERIA DE MINAS, METALURGIA Y AFINES',
    'INGENIER�A ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
    'INGENIER�A AGR�COLA, FORESTAL Y AFINES': 'INGENIERIA AGRICOLA, FORESTAL Y AFINES',
    'DEPORTES, EDUCACI�N F�SICA Y RECREACI�N': 'DEPORTES, EDUCACION FISICA Y RECREACION',
    'INGENIER�A AMBIENTAL, SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL, SANITARIA Y AFINES',
    'NUTRICI�N Y DIET�TICA': 'NUTRICION Y DIETETICA',
    'ANTROPOLOG�A O ARTES LIBERALES': 'ANTROPOLOGIA O ARTES LIBERALES',
    'LENGUAS MODERNAS, FILOLOG�A, LING��STICA Y AFINES': 'LENGUAS MODERNAS, FILOLOGIA, LINGUISTICA Y AFINES',
    'INGENIER�A AGROINDUSTRIAL, ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
    'M�SICA': 'MUSICA',
    'INGENIER�A BIOM�DICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
    'QU�MICA Y AFINES': 'QUIMICA Y AFINES',
    'INGENIER�A DE PETR�LEOS': 'INGENIERIA DE PETROLEOS',
    'F�SICA': 'FISICA',
    'OPTOMETR�A': 'OPTOMETRIA',
    'INGENIER�A AGRON�MICA, PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA, PECUARIA Y AFINES',
    'OTRAS INGENIER�AS': 'OTRAS INGENIERIAS',
    'FORMACI�N MILITAR': 'FORMACION MILITAR',
    'BIBLIOTECOLOG�A': 'BIBLIOTECOLOGIA',
    'TECNOLOG�AS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)': 'TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION (TIC)',
    'GEOGRAF�A O HISTORIA': 'GEOGRAFIA O HISTORIA',
    'EDUCACION FISICA Y RECREACI�N': 'EDUCACION FISICA Y RECREACION',
    'AVIACI�N': 'AVIACION',
    'DEPORTES, EDUCACION FISICA Y RECREACI�N': 'DEPORTES, EDUCACION FISICA Y RECREACION'
}

# Reemplazos en las columnas correspondientes
df['Área Conocimiento'] = df['Área Conocimiento'].replace(remplasos_area, regex=True)
df['Sub Area Conocimiento'] = df['Sub Area Conocimiento'].replace(remplazos_subarea, regex=True)

# Limpieza y estandarización de 'Nivel Académico'
df['Nivel Académico'] = df['Nivel Académico'].str.upper()
df['Nivel Académico'] = (df['Nivel Académico']
                         .str.replace('Á', 'A')
                         .str.replace('É', 'E')
                         .str.replace('Í', 'I')
                         .str.replace('Ó', 'O')
                         .str.replace('Ú', 'U')
                         .str.replace('�', ''))

df.loc[df['Nivel Académico'].str.contains('PRIMARIA', na=False), 'Nivel Académico'] = 'PRIMARIA'
df.loc[df['Nivel Académico'] == 'BACHILLERATO', 'Nivel Académico'] = 'BACHILLERATO'

df.loc[df['Nivel Académico'].str.contains(
    'TECNIC|TCNIC|TCN|TECNOL', na=False
), 'Nivel Académico'] = 'TECNICO PROFESIONAL'

df.loc[df['Nivel Académico'].isin([
    'PREGRADO - PROFESIONAL', 'PREGRADO PROFESIONAL', 'PREGRADO', 'UNIVERSITARIO'
]), 'Nivel Académico'] = 'PREGRADO'

df.loc[df['Nivel Académico'].str.contains('ESPECIAL', na=False), 'Nivel Académico'] = 'ESPECIALIZACION'
df.loc[df['Nivel Académico'].str.contains('MAEST', na=False), 'Nivel Académico'] = 'MAESTRIA'
df.loc[df['Nivel Académico'].str.contains('DOCTOR', na=False), 'Nivel Académico'] = 'DOCTORADO'

df.loc[df['Nivel Académico'].isin([
    'NO INDICA', '(NO REGISTRA)', 'NINGUNO', 'SIN PROFESION', 'SIN PROFESI', 'SIN PROFESIN'
]), 'Nivel Académico'] = 'NO REGISTRA'


#OBTENCIÓN DE DATOS SOLO DE COLOMBIA

#dividimos la columna de ciudad de nacimiento en tres columnas con informacion del pais, departamento y ciudad
df[['pais de origen', 'departamento de origen', 'Ciudad de Nacimiento']] = df['Ciudad de Nacimiento'].str.split('/', expand=True)


# filtramos los datos de personas solo nacidas en Colombia
df = df[df['pais de origen'] == 'COLOMBIA']

# Dividimos la columna 'Ciudad de Residencia' en 'Ciudad de residencia' y 'Estado de residencia'
df[['Ciudad de residencia', 'Estado de residencia']] = df['Ciudad de Residencia'].str.split('/', expand=True)

# Extracción del año y hora de registro
df[['Año de Registro', 'Hora de Registro']] = df['Fecha de Registro'].str.split('-', expand=True)

# Manejo de valores faltantes y limpieza adicional
condicion1 = df['Área Conocimiento'].isin(['NINGUNA', 'NO INDICA', '(NO REGISTRA)'])
condicion2= df['Sub Area Conocimiento'].isin(['NINGUNA', 'NO INDICA', '(NO REGISTRA)'])
df.loc[condicion1, 'Área Conocimiento'] = 'NINGUNA'
df.loc[condicion2, 'Sub Area Conocimiento'] = 'NINGUNA'

# Eliminación de filas con inconsistencias
cond = (
    (df['Área Conocimiento'] != 'NINGUNA') &
    (df['Nivel Académico'].isin(['NO INDICA', 'NINGUNO']))
)

df = df[~cond]

df = df[df['Año de Registro'] != '1900']

#corrección de etnias con caracteres especiales
df['Etnia de la persona'] = df['Etnia de la persona'].replace('IND�GENA', 'INDIGENA')
# Eliminación de columnas innecesarias
Df_final = df.drop(columns=['Código ISO país', 'Oficina de registro', 'Hora de Registro','Cantidad de personas',
                             'Estado civil', 'Edad (años)', 'Estatura (CM)', 'Localización','Fecha de Registro', 'Ciudad de Residencia'])
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_8752\864485981.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Ciudad de residencia', 'Estado de residencia']] = df['Ciudad de Residencia'].str.split('/', expand=True)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_8752\864485981.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Ciudad de residencia', 'Estado de residencia']] = df['Ciudad de Residencia'].str.split('/', expand=True)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_8752\864485981.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Año de Registro', 'Hora de Registro']] = df['Fecha de Registro'].str.split('-', expand=True)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_8752\864485981.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Año de Registro', 'Hora de Registro']] = df['Fecha de Registro'].str.split('-', expand=True)

# %%
#verificar los valores únicos después de la corrección
df['Área Conocimiento'].unique()
# Out:
# array(['NINGUNA', 'CIENCIAS SOCIALES Y HUMANAS',
#        'ECONOMIA, ADMINISTRACION CONTADURIA Y AFINES',
#        'INGENIERIA, ARQUITECTURA Y AFINES', 'CIENCIAS DE LA SALUD',
#        'AGRONOMIA, VETERINARIA Y AFINES', 'SERVICIOS', 'BELLAS ARTES',
#        'AGRONOMIA, VETERINARIA Y ZOOTECNIA', 'CIENCIAS DE LA EDUCACION',
#        'CIENCIAS SOCIALES, PERIODISMO E INFORMACION',
#        'MATEMATICAS Y CIENCIAS NATURALES', 'SALUD Y BIENESTAR',
#        'ADMINISTRACION DE EMPRESAS Y DERECHO', 'EDUCACION',
#        'INGENIERIA, INDUSTRIA Y CONSTRUCCI�N', 'COCINA Y CULINARIA',
#        'CIENCIAS NATURALES, MATEMATICAS Y ESTADISTICA', 'AVIACION',
#        'ARTES Y HUMANIDADES',
#        'TECNOLOGIAS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)',
#        'PROGRAMAS Y CERTIFICACIONES GENERICAS',
#        'AGROPECUARIO, SILVICULTURA, PESCA, Y VETERINARIA'], dtype=object)

# %%
df['Sub Area Conocimiento'].unique()
# Out:
# array(['NINGUNA', 'PERIODISMO, COMUNICACION SOCIAL Y AFINES',
#        'ADMINISTRACION', 'INGENIERIA INDUSTRIAL Y AFINES',
#        'SOCIOLOGIA, TRABAJO SOCIAL Y AFINES',
#        'OTROS ESTUDIOS EN CIENCIAS SOCIALES Y HUMANAS', 'MEDICINA',
#        'ARQUITECTURA', 'CONTADURIA PUBLICA', 'INGENIERIA CIVIL Y AFINES',
#        'AGRONOMIA', 'AVIACION', 'INGENIERIA MECANICA Y AFINES',
#        'OTRO PROGRAMA DE SALUD', 'PSICOLOGIA Y AFINES',
#        'SALUD OCUPACIONAL (HSEQ)', 'ECONOMIA', 'DISENO',
#        'INGENIERIA ELECTRICA Y AFINES', 'ZOOTECNIA',
#        'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES',
#        'INGENIERIA EN SISTEMAS, TELEMATICA Y AFINES', 'TERAPIAS',
#        'MEDICINA VETERINARIA',
#        'CIENCIA POLITICA Y/O RELACIONES INTERNACIONALES', 'EDUCACION',
#        'OTRAS INGENIERIAS', 'DERECHO Y AFINES', 'ENFERMERIA',
#        'PUBLICIDAD Y AFINES', 'FILOSOFIA, TEOLOGIA Y AFINES',
#        'COCINA Y CULINARIA', 'GEOLOGIA', 'ODONTOLOGIA',
#        'INGENIERIA QUIMICA Y AFINES', 'OTRO PROGRAMA DE BELLAS ARTES',
#        'OTROS PROGRAMAS DE CIENCIAS NATURALES',
#        'ARTES DRAMATICAS Y REPRESENTATIVAS', 'BACTERIOLOGIA',
#        'SALUD PUBLICA', 'MATEMATICAS, ESTADISTICA Y AFINES',
#        'ARTES PLASTICAS, VISUALES Y AFINES', 'INSTRUMENTACION QUIRURGICA',
#        'BIOLOGIA, MICROBIOLOGIA Y AFINES',
#        'INGENIERIA DE MINAS, METALURGIA Y AFINES',
#        'INGENIERIA ADMINISTRATIVA Y AFINES',
#        'DEPORTES, EDUCACION FISICA Y RECREACI�N', 'GEOGRAFIA O HISTORIA',
#        'INGENIERIA AMBIENTAL, SANITARIA Y AFINES',
#        'NUTRICION Y DIETETICA', 'DERECHO',
#        'ANTROPOLOGIA O ARTES LIBERALES',
#        'LENGUAS MODERNAS, FILOLOGIA, LINGUISTICA Y AFINES',
#        'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES', 'MUSICA',
#        'FORMACION MILITAR', 'INGENIERIA BIOMEDICA Y AFINES',
#        'INGENIERIA AGRICOLA, FORESTAL Y AFINES',
#        'INGENIERIA DE PETROLEOS', 'QUIMICA Y AFINES', 'FISICA',
#        'TECNOLOG�AS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)',
#        'OPTOMETRIA', 'BIBLIOTECOLOGIA',
#        'INGENIERIA AGRONOMICA, PECUARIA Y AFINES'], dtype=object)

# %%
#toque final para corregir los dos valores que quedaron con caracteres especiales
condicion1 =df['Área Conocimiento'] == 'INGENIERIA, INDUSTRIA Y CONSTRUCCI�N'
condicion2 =df['Sub Area Conocimiento'] == 'DEPORTES, EDUCACION FISICA Y RECREACI�N'
condicion3 = df['Área Conocimiento'] == 'TECNOLOGIAS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)'
condicion4 = df['Sub Area Conocimiento'] == 'TECNOLOG�AS DE LA INFORMACI�N Y LA COMUNICACI�N (TIC)'

df.loc[condicion1, 'Área Conocimiento'] = 'INGENIERIA, INDUSTRIA Y CONSTRUCCION'
df.loc[condicion2, 'Sub Area Conocimiento'] = 'DEPORTES, EDUCACION FISICA Y RECREACION'
df.loc[condicion3, 'Área Conocimiento'] = 'TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION (TIC)'
df.loc[condicion4, 'Sub Area Conocimiento'] = 'TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION (TIC)'

# %%
#comprobar los valores únicos después de la corrección
print(df['Área Conocimiento'].unique())
print(df['Sub Area Conocimiento'].unique())
# Out:
# ['NINGUNA' 'CIENCIAS SOCIALES Y HUMANAS'
#  'ECONOMIA, ADMINISTRACION CONTADURIA Y AFINES'
#  'INGENIERIA, ARQUITECTURA Y AFINES' 'CIENCIAS DE LA SALUD'
#  'AGRONOMIA, VETERINARIA Y AFINES' 'SERVICIOS' 'BELLAS ARTES'
#  'AGRONOMIA, VETERINARIA Y ZOOTECNIA' 'CIENCIAS DE LA EDUCACION'
#  'CIENCIAS SOCIALES, PERIODISMO E INFORMACION'
#  'MATEMATICAS Y CIENCIAS NATURALES' 'SALUD Y BIENESTAR'
#  'ADMINISTRACION DE EMPRESAS Y DERECHO' 'EDUCACION'
#  'INGENIERIA, INDUSTRIA Y CONSTRUCCION' 'COCINA Y CULINARIA'
#  'CIENCIAS NATURALES, MATEMATICAS Y ESTADISTICA' 'AVIACION'
#  'ARTES Y HUMANIDADES'
#  'TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION (TIC)'
#  'PROGRAMAS Y CERTIFICACIONES GENERICAS'
#  'AGROPECUARIO, SILVICULTURA, PESCA, Y VETERINARIA']
# ['NINGUNA' 'PERIODISMO, COMUNICACION SOCIAL Y AFINES' 'ADMINISTRACION'
#  'INGENIERIA INDUSTRIAL Y AFINES' 'SOCIOLOGIA, TRABAJO SOCIAL Y AFINES'
#  'OTROS ESTUDIOS EN CIENCIAS SOCIALES Y HUMANAS' 'MEDICINA' 'ARQUITECTURA'
#  'CONTADURIA PUBLICA' 'INGENIERIA CIVIL Y AFINES' 'AGRONOMIA' 'AVIACION'
#  'INGENIERIA MECANICA Y AFINES' 'OTRO PROGRAMA DE SALUD'
#  'PSICOLOGIA Y AFINES' 'SALUD OCUPACIONAL (HSEQ)' 'ECONOMIA' 'DISENO'
#  'INGENIERIA ELECTRICA Y AFINES' 'ZOOTECNIA'
#  'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES'
#  'INGENIERIA EN SISTEMAS, TELEMATICA Y AFINES' 'TERAPIAS'
#  'MEDICINA VETERINARIA' 'CIENCIA POLITICA Y/O RELACIONES INTERNACIONALES'
#  'EDUCACION' 'OTRAS INGENIERIAS' 'DERECHO Y AFINES' 'ENFERMERIA'
#  'PUBLICIDAD Y AFINES' 'FILOSOFIA, TEOLOGIA Y AFINES' 'COCINA Y CULINARIA'
#  'GEOLOGIA' 'ODONTOLOGIA' 'INGENIERIA QUIMICA Y AFINES'
#  'OTRO PROGRAMA DE BELLAS ARTES' 'OTROS PROGRAMAS DE CIENCIAS NATURALES'
#  'ARTES DRAMATICAS Y REPRESENTATIVAS' 'BACTERIOLOGIA' 'SALUD PUBLICA'
#  'MATEMATICAS, ESTADISTICA Y AFINES' 'ARTES PLASTICAS, VISUALES Y AFINES'
#  'INSTRUMENTACION QUIRURGICA' 'BIOLOGIA, MICROBIOLOGIA Y AFINES'
#  'INGENIERIA DE MINAS, METALURGIA Y AFINES'
#  'INGENIERIA ADMINISTRATIVA Y AFINES'
#  'DEPORTES, EDUCACION FISICA Y RECREACION' 'GEOGRAFIA O HISTORIA'
#  'INGENIERIA AMBIENTAL, SANITARIA Y AFINES' 'NUTRICION Y DIETETICA'
#  'DERECHO' 'ANTROPOLOGIA O ARTES LIBERALES'
#  'LENGUAS MODERNAS, FILOLOGIA, LINGUISTICA Y AFINES'
#  'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES' 'MUSICA'
#  'FORMACION MILITAR' 'INGENIERIA BIOMEDICA Y AFINES'
#  'INGENIERIA AGRICOLA, FORESTAL Y AFINES' 'INGENIERIA DE PETROLEOS'
#  'QUIMICA Y AFINES' 'FISICA'
#  'TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACION (TIC)' 'OPTOMETRIA'
#  'BIBLIOTECOLOGIA' 'INGENIERIA AGRONOMICA, PECUARIA Y AFINES']

# %%
#Guardar el DataFrame limpio en un archivo parquet
df.to_parquet("data/migrantes.parquet", index=False)
