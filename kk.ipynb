# %%
import pandas as pd

df = pd.read_excel('data/Colombianos_registrados_en_el_exterior_20251113 (1).xlsx', engine='openpyxl')

# %%
df['Nivel Académico'].unique()
# Out:
# array(['BACHILLERATO', 'NO REGISTRA', 'PREGRADO', 'ESPECIALIZACION',
#        'PRIMARIA', 'MAESTRIA', 'TECNICO PROFESIONAL', 'DOCTORADO'],
#       dtype=object)
